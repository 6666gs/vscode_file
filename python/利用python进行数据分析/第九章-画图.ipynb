# %% [markdown]
# # 画图学习

# %% [markdown]
# ## 1、简单入门

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
import numpy as np
data=np.arange(10)
plt.plot(data)
# Out:
# <div id='df322941-66bd-41eb-b4d5-9be852471fe7'></div>

# %%
'''
子图绘画
'''

fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
plt.plot(np.random.randn(30).cumsum(),'ko--')

ax2=fig.add_subplot(2,2,2)
plt.hist(np.random.randn(500),bins=50,color='b',alpha=0.5)

ax3=fig.add_subplot(2,2,3)
plt.scatter(np.arange(30),np.arange(30)+3*np.random.randn(30))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
'''
使用plt.subplots直接生成子图
'''

fig,axes=plt.subplots(2,2,sharex=True,sharey=True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(500),bins=50,color='k',alpha=0.5)
plt.subplots_adjust(wspace=0,hspace=0)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
'''
设置标题、轴标签、刻度、刻度标签
'''

fig=plt.figure()
ax=fig.add_subplot(1,1,1)
ax.plot(np.random.randn(1000),color='k')
ticks=ax.set_xticks([0,250,500,750,1000])
labels=ax.set_xticklabels(['one','two','three','four','five'],rotation=30,fontsize='small')
ax.set_title('random plot')
ax.set_xlabel('stages')
ax.set_ylabel('point')


'''
快速复制属性的方法
'''
props={
    'title':'random plot',
    'xlabel':'Stages',
    'ylabel':'point',
    'xticks':[0,250,500,750,1000]
}
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
ax.plot(np.random.randn(1000).cumsum())
ax.set(**props)


fig=plt.figure()
ax=fig.add_subplot(1,1,1)
ax.plot(np.random.randn(1000).cumsum(),'k',label='one')
ax.plot(np.random.randn(1000).cumsum(),'k--',label='two')
ax.plot(np.random.randn(1000).cumsum(),'k.',label='three')
ax.legend(loc='best')
ax.asof('three')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 36
#      34 ax.plot(np.random.randn(1000).cumsum(),'k.',label='three')
#      35 ax.legend(loc='best')
# ---> 36 ax.asof('three')
#
# AttributeError: 'Axes' object has no attribute 'asof'
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
'''
注释和图片加工
'''
from datetime import datetime
print(datetime(2007,10,11))
# Out:
# 2007-10-11 00:00:00

# %%
dict?
# Out:
# Init signature: dict(self, /, *args, **kwargs)
# Docstring:
# dict() -> new empty dictionary
# dict(mapping) -> new dictionary initialized from a mapping object's
#     (key, value) pairs
# dict(iterable) -> new dictionary initialized as if via:
#     d = {}
#     for k, v in iterable:
#         d[k] = v
# dict(**kwargs) -> new dictionary initialized with the name=value pairs
#     in the keyword argument list.  For example:  dict(one=1, two=2)
# Type:           type
# Subclasses:     OrderedDict, defaultdict, Counter, _EnumDict, Bunch, _Quoter, ObjectDict, StgDict, ConvertingDict, Config, ...
